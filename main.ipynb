# %%
from data

# %%
path = "/mnt/disk3/ducntm/FUGC2025/DATA/labeled_data/labels/0001.png"

# %%
img = Image.open(path)

# %%
img_array = np.asarray(img)

# Find all unique values
unique_values = np.unique(img_array)

print("Unique values in the image array:", unique_values)
# Out:
# Unique values in the image array: [0 1 2]

# %%
# img_array = np.random.choice([0, 1, 2], size=(10, 10), p=[0.5, 0.3, 0.2])

# Create a custom color map
cmap = ListedColormap(['red', 'green', 'blue'])

# Plot the image
plt.figure(figsize=(8, 8))
plt.imshow(img_array, cmap=cmap, interpolation='nearest')
plt.colorbar(ticks=[0, 1, 2])
plt.title('Semantic Segmentation Visualization')
plt.show()
